# %%
import numpy as np
import pandas as pd

# %%
eco_data = pd.read_excel("./eco.xls", sheet_name='All persons')
crime_data = pd.read_excel("./crime.xlsx", sheet_name='Crime Rates')

# %%
eco_code = eco_data['Unnamed: 0']
crime_code =

# %%
print(crime_data)
# Out:
#    Unnamed: 0              Unnamed: 1 All recorded offences Unnamed: 3  \
# 0        Code                 Borough               1999-00    2000-01
# 1         NaN                     NaN                   NaN        NaN
# 2   E09000002    Barking and Dagenham               120.454    123.575
# 3   E09000003                  Barnet               97.9618    95.6762
# 4   E09000004                  Bexley               95.0988    96.3437
# 5   E09000005                   Brent                127.74    122.716
# 6   E09000006                 Bromley               89.7722    88.5218
# 7   E09000007                  Camden               241.049    238.452
# 8   E09000008                 Croydon               113.661    105.376
# 9   E09000009                  Ealing               128.161    126.727
# 10  E09000010                 Enfield               104.821    101.862
# 11  E09000011               Greenwich               141.355    131.343
# ...

# %%
data_crime['Code'][0:40]
# Out:
# 0     E09000002
# 1     E09000003
# 2     E09000004
# 3     E09000005
# 4     E09000006
# 5     E09000007
# 6     E09000008
# 7     E09000009
# 8     E09000010
# 9     E09000011
# 10    E09000012
# 11    E09000013
# 12    E09000014
# 13    E09000015
# 14    E09000016
# 15    E09000017
# 16    E09000018
# 17    E09000019
# 18    E09000020
# 19    E09000021
# 20    E09000022
# 21    E09000023
# 22    E09000024
# 23    E09000025
# 24    E09000026
# 25    E09000027
# 26    E09000028
# 27    E09000029
# 28    E09000030
# 29    E09000031
# 30    E09000032
# 31    E09000033
# 32          NaN
# 33    E13000001
# 34    E13000002
# 35    E12000007
# 36          727
# 37    E09000002
# 38    E09000003
# 39    E09000004
# Name: Code, dtype: object
